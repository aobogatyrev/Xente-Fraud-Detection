# %% [markdown]
# # Bagging Classifier on top k chi2

# %%
import numpy as np
import pandas as pd

# %%
df_trn = pd.read_csv('../data/train-agg-cut.csv')

# %% [markdown]
# ## Univariate Selection $\chi^2$

# %% [markdown]
# ### Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
def scaleColumns(data, cols_to_scale, scaler):
    for col in cols_to_scale:
        data[col] = pd.DataFrame(scaler.fit_transform(pd.DataFrame(data[col])))

# %%
scaleColumns(df_trn, list(df_trn.columns), MinMaxScaler())

# %%
X_trn = df_trn.drop(columns=['FraudResult'], axis=1)
y_trn = df_trn['FraudResult']

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
#apply SelectKBest class to extract top 400 best features
k = 400
bestfeatures = SelectKBest(score_func=chi2, k=k)
fit = bestfeatures.fit(X_trn, y_trn)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X_trn.columns)

#concat two dataframes for better visualization
featureScores = pd.concat([dfcolumns, dfscores], axis=1)
featureScores.columns = ['Features', 'Score']  # naming the dataframe columns
featureScores.nlargest(k, 'Score')             # print best features
# Out:
#                                               Features        Score
# 496                                     AmountPositive  5597.219242
# 0                                                Value  4762.582809
# 86   account_product_transactions__AmountPositive_g...   883.548964
# 390  account_provider_transactions__AmountPositive_...   739.340503
# 311  account_product_category_transactions__AmountP...   691.669685
# 75     account_provider_transactions__Value_global_avg   570.979859
# 386  account_provider_transactions__AmountPositive_...   462.555515
# 296  account_channel_transactions__AmountPositive_g...   384.409342
# 90   account_product_transactions__AmountPositive_g...   383.886192
# 281    account_transactions__AmountPositive_global_sum   381.275567
# 446  account_pricing_strategy_transactions__AmountP...   372.565600
# 315  account_product_category_transactions__AmountP...   356.274749
# 76   account_product_transactions__AmountPositive_w...   319.413282
# 380  account_provider_transactions__AmountPositive_...   302.425837
# 450  account_pricing_strategy_transactions__AmountP...   292.863403
# 105     account_product_transactions__Value_global_avg   291.565427
# 330  account_product_category_transactions__Value_g...   272.484611
# 300  account_channel_transactions__AmountPositive_g...   271.570905
# 285    account_transactions__AmountPositive_global_avg   271.275782
# 376  account_provider_transactions__AmountPositive_...   254.274143
# 301  account_product_category_transactions__AmountP...   245.057613
# 240  account_pricing_strategy_transactions__Value_g...   226.938616
# 210     account_channel_transactions__Value_global_avg   214.109476
# 45              account_transactions__Value_global_avg   213.917605
# 146    product_transactions__AmountPositive_global_sum   209.361055
# 136      product_transactions__AmountPositive_week_sum   200.152606
# 65       account_provider_transactions__Value_week_avg   183.366838
# 141     product_transactions__AmountPositive_month_sum   182.767150
# 180   provider_transactions__AmountPositive_global_avg   173.284560
# 286  account_channel_transactions__AmountPositive_w...   171.520253
# ..                                                 ...          ...
# 365  account_product_category_transactions__AmountN...     1.083944
# 126     pricing_strategy_transactions__Value_month_sum     1.060263
# 241      product_category_transactions__Value_week_sum     1.041518
# 236  account_pricing_strategy_transactions__Value_g...     1.029351
# 250     product_category_transactions__Value_month_avg     0.989555
# 415  pricing_strategy_transactions__AmountNegative_...     0.968238
# 465  account_pricing_strategy_transactions__AmountN...     0.926178
# 395  account_product_transactions__AmountNegative_w...     0.806899
# 375  account_product_category_transactions__AmountN...     0.791133
# 435    account_transactions__AmountNegative_global_avg     0.788616
# 165  account_channel_transactions__AmountNegative_g...     0.788595
# 360  account_provider_transactions__AmountNegative_...     0.788595
# 460  account_pricing_strategy_transactions__AmountN...     0.672068
# 335  product_category_transactions__AmountPositive_...     0.651027
# 144     product_transactions__AmountPositive_month_max     0.650437
# 9                product_transactions__Value_month_max     0.649282
# 174    provider_transactions__AmountPositive_month_max     0.645204
# 416  pricing_strategy_transactions__AmountNegative_...     0.643190
# 264             provider_transactions__Value_month_max     0.641346
# 261             provider_transactions__Value_month_sum     0.640395
# 54      channel_transactions__AmountPositive_month_max     0.636538
# 189              channel_transactions__Value_month_max     0.632840
# 339  product_category_transactions__AmountPositive_...     0.625328
# 249     product_category_transactions__Value_month_max     0.625267
# 127   pricing_strategy_transactions__Value_month_count     0.623488
# 412  pricing_strategy_transactions__AmountNegative_...     0.623488
# 487  pricing_strategy_transactions__AmountPositive_...     0.623488
# 474     product_transactions__AmountNegative_month_max     0.623002
# 489  pricing_strategy_transactions__AmountPositive_...     0.620913
# 129     pricing_strategy_transactions__Value_month_max     0.620617
#
# [400 rows x 2 columns]

# %%
columns_top400_chi2 = list(featureScores.nlargest(k, 'Score').values[:, 0])

# %% [markdown]
# ## Подбор такого k, при котором есть отличия от уже submitted

# %%
df_trn = pd.read_csv('../data/train-agg-cut.csv')
df_tst = pd.read_csv('../data/test-agg-cut.csv')
df_sbm = pd.read_csv('../data/sample_submission.csv')

# %%
X_trn = df_trn.drop(columns=['FraudResult'], axis=1)
y_trn = df_trn['FraudResult']

X_tst = df_tst

# %%
import os
from collections import Counter
from sklearn.ensemble import BaggingClassifier

# %%
classifier = BaggingClassifier(n_estimators=100, n_jobs=-1)
for k in range(21, 401):
    # prepare dataset on k columns
    X_trn_drp = X_trn[columns_top400_chi2[:k]]
    X_tst_drp = X_tst[columns_top400_chi2[:k]]
    
    predict = classifier.fit(X_trn_drp, y_trn).predict(X_tst_drp)
    print(k, ':', Counter(predict))
    df_sbm['FraudResult'] = predict
    
    # определяем был ли ранее точно такой же результат
    current_subm_set = set(df_sbm[df_sbm['FraudResult'] == 1].index.tolist())
    # просматриваем все файлы в папке submitted
    is_exist = False
    files = os.listdir('../submitted')
    files.sort()
    for f in files:
        f_csv = pd.read_csv('../submitted/' + f)
        if set(f_csv[f_csv['FraudResult'] == 1].index.tolist()) == current_subm_set:
            is_exist = True    
    if is_exist:
        print('It is the same as in: ' + f)
    else:
        print('New result! Write it')
        df_sbm.to_csv('../submitted/AlBo0726_top' + str(k) + 'chi2_BaggingClassifier.csv', encoding='utf-8', index=False)
# Out:
# 21 : Counter({0: 44946, 1: 73})
# It is the same as in: AlBo0724_top20chi2_BaggingClassifier.csv
# 22 : Counter({0: 44946, 1: 73})
# It is the same as in: AlBo0724_top20chi2_BaggingClassifier.csv
# 23 : Counter({0: 44946, 1: 73})
# It is the same as in: AlBo0724_top20chi2_BaggingClassifier.csv
# 24 : Counter({0: 44946, 1: 73})
# It is the same as in: AlBo0724_top20chi2_BaggingClassifier.csv
# 25 : Counter({0: 44947, 1: 72})
# New result! Write it
# 26 : Counter({0: 44944, 1: 75})
# New result! Write it
# 27 : Counter({0: 44945, 1: 74})
# New result! Write it
# 28 : Counter({0: 44946, 1: 73})
# New result! Write it
# 29 : Counter({0: 44933, 1: 86})
# New result! Write it
# 30 : Counter({0: 44938, 1: 81})
# New result! Write it
# 31 : Counter({0: 44946, 1: 73})
# New result! Write it
# 32 : Counter({0: 44942, 1: 77})
# New result! Write it
# 33 : Counter({0: 44938, 1: 81})
# It is the same as in: AlBo0726_top32chi2_BaggingClassifier.csv
# 34 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top32chi2_BaggingClassifier.csv
# 35 : Counter({0: 44939, 1: 80})
# New result! Write it
# 36 : Counter({0: 44939, 1: 80})
# It is the same as in: AlBo0726_top35chi2_BaggingClassifier.csv
# 37 : Counter({0: 44938, 1: 81})
# It is the same as in: AlBo0726_top35chi2_BaggingClassifier.csv
# 38 : Counter({0: 44940, 1: 79})
# New result! Write it
# 39 : Counter({0: 44940, 1: 79})
# New result! Write it
# 40 : Counter({0: 44929, 1: 90})
# New result! Write it
# 41 : Counter({0: 44933, 1: 86})
# It is the same as in: AlBo0726_top40chi2_BaggingClassifier.csv
# 42 : Counter({0: 44929, 1: 90})
# It is the same as in: AlBo0726_top40chi2_BaggingClassifier.csv
# 43 : Counter({0: 44939, 1: 80})
# New result! Write it
# 44 : Counter({0: 44939, 1: 80})
# It is the same as in: AlBo0726_top43chi2_BaggingClassifier.csv
# 45 : Counter({0: 44938, 1: 81})
# It is the same as in: AlBo0726_top43chi2_BaggingClassifier.csv
# 46 : Counter({0: 44941, 1: 78})
# New result! Write it
# 47 : Counter({0: 44933, 1: 86})
# It is the same as in: AlBo0726_top46chi2_BaggingClassifier.csv
# 48 : Counter({0: 44939, 1: 80})
# It is the same as in: AlBo0726_top46chi2_BaggingClassifier.csv
# 49 : Counter({0: 44939, 1: 80})
# It is the same as in: AlBo0726_top46chi2_BaggingClassifier.csv
# 50 : Counter({0: 44939, 1: 80})
# It is the same as in: AlBo0726_top46chi2_BaggingClassifier.csv
# 51 : Counter({0: 44929, 1: 90})
# It is the same as in: AlBo0726_top46chi2_BaggingClassifier.csv
# 52 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top46chi2_BaggingClassifier.csv
# 53 : Counter({0: 44940, 1: 79})
# New result! Write it
# 54 : Counter({0: 44938, 1: 81})
# New result! Write it
# 55 : Counter({0: 44933, 1: 86})
# It is the same as in: AlBo0726_top54chi2_BaggingClassifier.csv
# 56 : Counter({0: 44939, 1: 80})
# It is the same as in: AlBo0726_top54chi2_BaggingClassifier.csv
# 57 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top54chi2_BaggingClassifier.csv
# 58 : Counter({0: 44939, 1: 80})
# It is the same as in: AlBo0726_top54chi2_BaggingClassifier.csv
# 59 : Counter({0: 44939, 1: 80})
# It is the same as in: AlBo0726_top54chi2_BaggingClassifier.csv
# 60 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top54chi2_BaggingClassifier.csv
# 61 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top54chi2_BaggingClassifier.csv
# 62 : Counter({0: 44940, 1: 79})
# New result! Write it
# 63 : Counter({0: 44945, 1: 74})
# New result! Write it
# 64 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top63chi2_BaggingClassifier.csv
# 65 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top63chi2_BaggingClassifier.csv
# 66 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top63chi2_BaggingClassifier.csv
# 67 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top63chi2_BaggingClassifier.csv
# 68 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top63chi2_BaggingClassifier.csv
# /home/abogatyrov/anaconda3/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# 69 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top63chi2_BaggingClassifier.csv
# 70 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top63chi2_BaggingClassifier.csv
# 71 : Counter({0: 44943, 1: 76})
# New result! Write it
# 72 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top71chi2_BaggingClassifier.csv
# 73 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top71chi2_BaggingClassifier.csv
# 74 : Counter({0: 44946, 1: 73})
# New result! Write it
# 75 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top74chi2_BaggingClassifier.csv
# 76 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top74chi2_BaggingClassifier.csv
# 77 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top74chi2_BaggingClassifier.csv
# 78 : Counter({0: 44937, 1: 82})
# New result! Write it
# 79 : Counter({0: 44943, 1: 76})
# It is the same as in: AlBo0726_top78chi2_BaggingClassifier.csv
# 80 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top78chi2_BaggingClassifier.csv
# 81 : Counter({0: 44945, 1: 74})
# It is the same as in: AlBo0726_top78chi2_BaggingClassifier.csv
# 82 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top78chi2_BaggingClassifier.csv
# 83 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top78chi2_BaggingClassifier.csv
# 84 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top78chi2_BaggingClassifier.csv
# 85 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top78chi2_BaggingClassifier.csv
# 86 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top78chi2_BaggingClassifier.csv
# 87 : Counter({0: 44941, 1: 78})
# New result! Write it
# 88 : Counter({0: 44946, 1: 73})
# It is the same as in: AlBo0726_top87chi2_BaggingClassifier.csv
# 89 : Counter({0: 44943, 1: 76})
# It is the same as in: AlBo0726_top87chi2_BaggingClassifier.csv
# 90 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top87chi2_BaggingClassifier.csv
# 91 : Counter({0: 44946, 1: 73})
# It is the same as in: AlBo0726_top87chi2_BaggingClassifier.csv
# 92 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top87chi2_BaggingClassifier.csv
# 93 : Counter({0: 44946, 1: 73})
# New result! Write it
# 94 : Counter({0: 44944, 1: 75})
# New result! Write it
# 95 : Counter({0: 44945, 1: 74})
# It is the same as in: AlBo0726_top94chi2_BaggingClassifier.csv
# 96 : Counter({0: 44941, 1: 78})
# New result! Write it
# 97 : Counter({0: 44937, 1: 82})
# New result! Write it
# 98 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 99 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 100 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 101 : Counter({0: 44940, 1: 79})
# New result! Write it
# 102 : Counter({0: 44947, 1: 72})
# New result! Write it
# 103 : Counter({0: 44947, 1: 72})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 104 : Counter({0: 44946, 1: 73})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 105 : Counter({0: 44946, 1: 73})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 106 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 107 : Counter({0: 44944, 1: 75})
# New result! Write it
# 108 : Counter({0: 44947, 1: 72})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 109 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 110 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 111 : Counter({0: 44945, 1: 74})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 112 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 113 : Counter({0: 44946, 1: 73})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 114 : Counter({0: 44943, 1: 76})
# New result! Write it
# 115 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 116 : Counter({0: 44940, 1: 79})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 117 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 118 : Counter({0: 44947, 1: 72})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 119 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 120 : Counter({0: 44946, 1: 73})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 121 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 122 : Counter({0: 44944, 1: 75})
# New result! Write it
# 123 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 124 : Counter({0: 44946, 1: 73})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 125 : Counter({0: 44947, 1: 72})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 126 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 127 : Counter({0: 44945, 1: 74})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 128 : Counter({0: 44947, 1: 72})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 129 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 130 : Counter({0: 44945, 1: 74})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 131 : Counter({0: 44938, 1: 81})
# New result! Write it
# 132 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 133 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 134 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 135 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 136 : Counter({0: 44945, 1: 74})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 137 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 138 : Counter({0: 44938, 1: 81})
# New result! Write it
# 139 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 140 : Counter({0: 44945, 1: 74})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 141 : Counter({0: 44946, 1: 73})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 142 : Counter({0: 44944, 1: 75})
# New result! Write it
# 143 : Counter({0: 44947, 1: 72})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 144 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 145 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 146 : Counter({0: 44947, 1: 72})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 147 : Counter({0: 44946, 1: 73})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 148 : Counter({0: 44946, 1: 73})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 149 : Counter({0: 44940, 1: 79})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 150 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 151 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 152 : Counter({0: 44937, 1: 82})
# New result! Write it
# 153 : Counter({0: 44945, 1: 74})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 154 : Counter({0: 44947, 1: 72})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 155 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 156 : Counter({0: 44946, 1: 73})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 157 : Counter({0: 44945, 1: 74})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 158 : Counter({0: 44939, 1: 80})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 159 : Counter({0: 44932, 1: 87})
# New result! Write it
# 160 : Counter({0: 44943, 1: 76})
# New result! Write it
# 161 : Counter({0: 44943, 1: 76})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 162 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 163 : Counter({0: 44933, 1: 86})
# New result! Write it
# 164 : Counter({0: 44940, 1: 79})
# New result! Write it
# 165 : Counter({0: 44932, 1: 87})
# New result! Write it
# 166 : Counter({0: 44932, 1: 87})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 167 : Counter({0: 44926, 1: 93})
# New result! Write it
# 168 : Counter({0: 44943, 1: 76})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 169 : Counter({0: 44943, 1: 76})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 170 : Counter({0: 44922, 1: 97})
# New result! Write it
# 171 : Counter({0: 44941, 1: 78})
# New result! Write it
# 172 : Counter({0: 44938, 1: 81})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 173 : Counter({0: 44933, 1: 86})
# New result! Write it
# 174 : Counter({0: 44943, 1: 76})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 175 : Counter({0: 44937, 1: 82})
# New result! Write it
# 176 : Counter({0: 44939, 1: 80})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 177 : Counter({0: 44936, 1: 83})
# New result! Write it
# 178 : Counter({0: 44942, 1: 77})
# New result! Write it
# 179 : Counter({0: 44942, 1: 77})
# New result! Write it
# 180 : Counter({0: 44935, 1: 84})
# New result! Write it
# 181 : Counter({0: 44938, 1: 81})
# New result! Write it
# 182 : Counter({0: 44947, 1: 72})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 183 : Counter({0: 44940, 1: 79})
# New result! Write it
# 184 : Counter({0: 44931, 1: 88})
# New result! Write it
# 185 : Counter({0: 44936, 1: 83})
# New result! Write it
# 186 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 187 : Counter({0: 44934, 1: 85})
# New result! Write it
# 188 : Counter({0: 44940, 1: 79})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 189 : Counter({0: 44938, 1: 81})
# New result! Write it
# 190 : Counter({0: 44932, 1: 87})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 191 : Counter({0: 44939, 1: 80})
# New result! Write it
# 192 : Counter({0: 44942, 1: 77})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 193 : Counter({0: 44933, 1: 86})
# New result! Write it
# 194 : Counter({0: 44931, 1: 88})
# New result! Write it
# 195 : Counter({0: 44943, 1: 76})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 196 : Counter({0: 44940, 1: 79})
# New result! Write it
# 197 : Counter({0: 44930, 1: 89})
# New result! Write it
# 198 : Counter({0: 44935, 1: 84})
# New result! Write it
# 199 : Counter({0: 44929, 1: 90})
# New result! Write it
# 200 : Counter({0: 44940, 1: 79})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 201 : Counter({0: 44946, 1: 73})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 202 : Counter({0: 44932, 1: 87})
# New result! Write it
# 203 : Counter({0: 44922, 1: 97})
# New result! Write it
# 204 : Counter({0: 44942, 1: 77})
# New result! Write it
# 205 : Counter({0: 44943, 1: 76})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 206 : Counter({0: 44932, 1: 87})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 207 : Counter({0: 44939, 1: 80})
# New result! Write it
# 208 : Counter({0: 44943, 1: 76})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 209 : Counter({0: 44938, 1: 81})
# New result! Write it
# 210 : Counter({0: 44917, 1: 102})
# New result! Write it
# 211 : Counter({0: 44930, 1: 89})
# New result! Write it
# 212 : Counter({0: 44931, 1: 88})
# New result! Write it
# 213 : Counter({0: 44939, 1: 80})
# New result! Write it
# 214 : Counter({0: 44937, 1: 82})
# New result! Write it
# 215 : Counter({0: 44937, 1: 82})
# New result! Write it
# 216 : Counter({0: 44935, 1: 84})
# New result! Write it
# 217 : Counter({0: 44938, 1: 81})
# New result! Write it
# 218 : Counter({0: 44944, 1: 75})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 219 : Counter({0: 44940, 1: 79})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 220 : Counter({0: 44939, 1: 80})
# New result! Write it
# 221 : Counter({0: 44936, 1: 83})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 222 : Counter({0: 44939, 1: 80})
# New result! Write it
# 223 : Counter({0: 44930, 1: 89})
# New result! Write it
# 224 : Counter({0: 44927, 1: 92})
# New result! Write it
# 225 : Counter({0: 44940, 1: 79})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 226 : Counter({0: 44936, 1: 83})
# New result! Write it
# 227 : Counter({0: 44930, 1: 89})
# New result! Write it
# 228 : Counter({0: 44937, 1: 82})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 229 : Counter({0: 44939, 1: 80})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 230 : Counter({0: 44941, 1: 78})
# New result! Write it
# 231 : Counter({0: 44936, 1: 83})
# New result! Write it
# 232 : Counter({0: 44928, 1: 91})
# New result! Write it
# 233 : Counter({0: 44930, 1: 89})
# New result! Write it
# 234 : Counter({0: 44935, 1: 84})
# New result! Write it
# 235 : Counter({0: 44933, 1: 86})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 236 : Counter({0: 44931, 1: 88})
# New result! Write it
# 237 : Counter({0: 44929, 1: 90})
# New result! Write it
# 238 : Counter({0: 44941, 1: 78})
# New result! Write it
# 239 : Counter({0: 44929, 1: 90})
# New result! Write it
# 240 : Counter({0: 44937, 1: 82})
# New result! Write it
# 241 : Counter({0: 44932, 1: 87})
# New result! Write it
# 242 : Counter({0: 44929, 1: 90})
# New result! Write it
# 243 : Counter({0: 44934, 1: 85})
# New result! Write it
# 244 : Counter({0: 44938, 1: 81})
# New result! Write it
# 245 : Counter({0: 44931, 1: 88})
# New result! Write it
# 246 : Counter({0: 44929, 1: 90})
# New result! Write it
# 247 : Counter({0: 44933, 1: 86})
# New result! Write it
# 248 : Counter({0: 44929, 1: 90})
# New result! Write it
# 249 : Counter({0: 44934, 1: 85})
# New result! Write it
# 250 : Counter({0: 44922, 1: 97})
# New result! Write it
# 251 : Counter({0: 44945, 1: 74})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 252 : Counter({0: 44937, 1: 82})
# New result! Write it
# 253 : Counter({0: 44938, 1: 81})
# New result! Write it
# 254 : Counter({0: 44933, 1: 86})
# New result! Write it
# 255 : Counter({0: 44939, 1: 80})
# New result! Write it
# 256 : Counter({0: 44936, 1: 83})
# New result! Write it
# 257 : Counter({0: 44941, 1: 78})
# New result! Write it
# 258 : Counter({0: 44936, 1: 83})
# New result! Write it
# 259 : Counter({0: 44935, 1: 84})
# New result! Write it
# 260 : Counter({0: 44942, 1: 77})
# New result! Write it
# 261 : Counter({0: 44934, 1: 85})
# New result! Write it
# 262 : Counter({0: 44939, 1: 80})
# New result! Write it
# 263 : Counter({0: 44925, 1: 94})
# New result! Write it
# 264 : Counter({0: 44943, 1: 76})
# New result! Write it
# 265 : Counter({0: 44940, 1: 79})
# New result! Write it
# 266 : Counter({0: 44936, 1: 83})
# New result! Write it
# 267 : Counter({0: 44938, 1: 81})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 268 : Counter({0: 44939, 1: 80})
# New result! Write it
# 269 : Counter({0: 44942, 1: 77})
# New result! Write it
# 270 : Counter({0: 44942, 1: 77})
# New result! Write it
# 271 : Counter({0: 44940, 1: 79})
# New result! Write it
# 272 : Counter({0: 44939, 1: 80})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 273 : Counter({0: 44939, 1: 80})
# New result! Write it
# 274 : Counter({0: 44941, 1: 78})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 275 : Counter({0: 44935, 1: 84})
# New result! Write it
# 276 : Counter({0: 44938, 1: 81})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 277 : Counter({0: 44933, 1: 86})
# New result! Write it
# 278 : Counter({0: 44937, 1: 82})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 279 : Counter({0: 44932, 1: 87})
# New result! Write it
# 280 : Counter({0: 44939, 1: 80})
# New result! Write it
# 281 : Counter({0: 44938, 1: 81})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 282 : Counter({0: 44928, 1: 91})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 283 : Counter({0: 44945, 1: 74})
# New result! Write it
# 284 : Counter({0: 44941, 1: 78})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 285 : Counter({0: 44944, 1: 75})
# New result! Write it
# 286 : Counter({0: 44943, 1: 76})
# New result! Write it
# 287 : Counter({0: 44940, 1: 79})
# New result! Write it
# 288 : Counter({0: 44940, 1: 79})
# New result! Write it
# 289 : Counter({0: 44939, 1: 80})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 290 : Counter({0: 44938, 1: 81})
# New result! Write it
# 291 : Counter({0: 44931, 1: 88})
# New result! Write it
# 292 : Counter({0: 44946, 1: 73})
# New result! Write it
# 293 : Counter({0: 44941, 1: 78})
# New result! Write it
# 294 : Counter({0: 44944, 1: 75})
# New result! Write it
# 295 : Counter({0: 44936, 1: 83})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 296 : Counter({0: 44941, 1: 78})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 297 : Counter({0: 44941, 1: 78})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 298 : Counter({0: 44943, 1: 76})
# New result! Write it
# 299 : Counter({0: 44938, 1: 81})
# New result! Write it
# 300 : Counter({0: 44943, 1: 76})
# New result! Write it
# 301 : Counter({0: 44939, 1: 80})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 302 : Counter({0: 44933, 1: 86})
# New result! Write it
# 303 : Counter({0: 44937, 1: 82})
# New result! Write it
# 304 : Counter({0: 44940, 1: 79})
# New result! Write it
# 305 : Counter({0: 44942, 1: 77})
# New result! Write it
# 306 : Counter({0: 44941, 1: 78})
# New result! Write it
# 307 : Counter({0: 44937, 1: 82})
# New result! Write it
# 308 : Counter({0: 44943, 1: 76})
# New result! Write it
# 309 : Counter({0: 44945, 1: 74})
# New result! Write it
# 310 : Counter({0: 44936, 1: 83})
# New result! Write it
# 311 : Counter({0: 44933, 1: 86})
# New result! Write it
# 312 : Counter({0: 44928, 1: 91})
# New result! Write it
# 313 : Counter({0: 44935, 1: 84})
# New result! Write it
# 314 : Counter({0: 44932, 1: 87})
# New result! Write it
# 315 : Counter({0: 44944, 1: 75})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 316 : Counter({0: 44947, 1: 72})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 317 : Counter({0: 44930, 1: 89})
# New result! Write it
# 318 : Counter({0: 44926, 1: 93})
# New result! Write it
# 319 : Counter({0: 44931, 1: 88})
# New result! Write it
# 320 : Counter({0: 44940, 1: 79})
# New result! Write it
# 321 : Counter({0: 44942, 1: 77})
# New result! Write it
# 322 : Counter({0: 44940, 1: 79})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 323 : Counter({0: 44935, 1: 84})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 324 : Counter({0: 44935, 1: 84})
# New result! Write it
# 325 : Counter({0: 44944, 1: 75})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 326 : Counter({0: 44933, 1: 86})
# New result! Write it
# 327 : Counter({0: 44933, 1: 86})
# New result! Write it
# 328 : Counter({0: 44935, 1: 84})
# New result! Write it
# 329 : Counter({0: 44926, 1: 93})
# New result! Write it
# 330 : Counter({0: 44930, 1: 89})
# New result! Write it
# 331 : Counter({0: 44928, 1: 91})
# New result! Write it
# 332 : Counter({0: 44927, 1: 92})
# New result! Write it
# 333 : Counter({0: 44940, 1: 79})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 334 : Counter({0: 44939, 1: 80})
# New result! Write it
# 335 : Counter({0: 44939, 1: 80})
# New result! Write it
# 336 : Counter({0: 44931, 1: 88})
# New result! Write it
# 337 : Counter({0: 44936, 1: 83})
# New result! Write it
# 338 : Counter({0: 44938, 1: 81})
# New result! Write it
# 339 : Counter({0: 44939, 1: 80})
# New result! Write it
# 340 : Counter({0: 44924, 1: 95})
# New result! Write it
# 341 : Counter({0: 44940, 1: 79})
# New result! Write it
# 342 : Counter({0: 44940, 1: 79})
# New result! Write it
# 343 : Counter({0: 44939, 1: 80})
# New result! Write it
# 344 : Counter({0: 44937, 1: 82})
# New result! Write it
# 345 : Counter({0: 44942, 1: 77})
# New result! Write it
# 346 : Counter({0: 44935, 1: 84})
# New result! Write it
# 347 : Counter({0: 44933, 1: 86})
# New result! Write it
# 348 : Counter({0: 44937, 1: 82})
# New result! Write it
# 349 : Counter({0: 44917, 1: 102})
# New result! Write it
# 350 : Counter({0: 44935, 1: 84})
# New result! Write it
# 351 : Counter({0: 44929, 1: 90})
# New result! Write it
# 352 : Counter({0: 44940, 1: 79})
# New result! Write it
# 353 : Counter({0: 44932, 1: 87})
# New result! Write it
# 354 : Counter({0: 44935, 1: 84})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 355 : Counter({0: 44937, 1: 82})
# New result! Write it
# 356 : Counter({0: 44932, 1: 87})
# New result! Write it
# 357 : Counter({0: 44935, 1: 84})
# New result! Write it
# 358 : Counter({0: 44934, 1: 85})
# New result! Write it
# 359 : Counter({0: 44939, 1: 80})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 360 : Counter({0: 44935, 1: 84})
# New result! Write it
# 361 : Counter({0: 44931, 1: 88})
# New result! Write it
# 362 : Counter({0: 44935, 1: 84})
# New result! Write it
# 363 : Counter({0: 44939, 1: 80})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 364 : Counter({0: 44938, 1: 81})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 365 : Counter({0: 44929, 1: 90})
# New result! Write it
# 366 : Counter({0: 44928, 1: 91})
# New result! Write it
# 367 : Counter({0: 44943, 1: 76})
# New result! Write it
# 368 : Counter({0: 44939, 1: 80})
# New result! Write it
# 369 : Counter({0: 44941, 1: 78})
# New result! Write it
# 370 : Counter({0: 44927, 1: 92})
# New result! Write it
# 371 : Counter({0: 44933, 1: 86})
# New result! Write it
# 372 : Counter({0: 44930, 1: 89})
# New result! Write it
# 373 : Counter({0: 44931, 1: 88})
# New result! Write it
# 374 : Counter({0: 44925, 1: 94})
# New result! Write it
# 375 : Counter({0: 44926, 1: 93})
# New result! Write it
# 376 : Counter({0: 44925, 1: 94})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 377 : Counter({0: 44933, 1: 86})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 378 : Counter({0: 44925, 1: 94})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 379 : Counter({0: 44931, 1: 88})
# New result! Write it
# 380 : Counter({0: 44930, 1: 89})
# New result! Write it
# 381 : Counter({0: 44924, 1: 95})
# New result! Write it
# 382 : Counter({0: 44916, 1: 103})
# New result! Write it
# 383 : Counter({0: 44929, 1: 90})
# New result! Write it
# 384 : Counter({0: 44925, 1: 94})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 385 : Counter({0: 44917, 1: 102})
# New result! Write it
# 386 : Counter({0: 44920, 1: 99})
# New result! Write it
# 387 : Counter({0: 44933, 1: 86})
# New result! Write it
# 388 : Counter({0: 44921, 1: 98})
# New result! Write it
# 389 : Counter({0: 44936, 1: 83})
# New result! Write it
# 390 : Counter({0: 44930, 1: 89})
# New result! Write it
# 391 : Counter({0: 44937, 1: 82})
# New result! Write it
# 392 : Counter({0: 44930, 1: 89})
# New result! Write it
# 393 : Counter({0: 44927, 1: 92})
# New result! Write it
# 394 : Counter({0: 44933, 1: 86})
# New result! Write it
# 395 : Counter({0: 44927, 1: 92})
# New result! Write it
# 396 : Counter({0: 44927, 1: 92})
# New result! Write it
# 397 : Counter({0: 44916, 1: 103})
# New result! Write it
# 398 : Counter({0: 44924, 1: 95})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 399 : Counter({0: 44932, 1: 87})
# It is the same as in: AlBo0726_top97chi2_BaggingClassifier.csv
# 400 : Counter({0: 44918, 1: 101})
# New result! Write it

# %% [markdown]
# `k   F1-score on zindi`
#
# `20  0.813559322033898`
#
# `25  0.793103448275862`
#
# `26  0.793103448275862`
#
# `27  0.793103448275862`
#
# `28  0.793103448275862`
#
# `29  0.696969696969697`
#
# `30  0.73015873015873`
#
# `31  0.793103448275862`
#
# `32  0.754098360655738`
#
# `35  0.741935483870968`
#
# `38  0.721311475409836`
#
# `39  0.754098360655738`
#
# `40  0.676470588235294`
#
# `43  0.741935483870968`
#
# `46  0.733333333333333`
#
# `53  0.754098360655738`
#
# `54  0.741935483870968`
#
# `62  0.741935483870968`
#
# `63  0.779661016949153`
#
# `71  0.733333333333333`

# %%
for n_frauds in range(70, 100):
    for n_frauds_pred in range(70, 100):

# %%
def f1_score
